# %%
import pandas as pd

# %%
# Load the CSV file, one-hot encode the 'category' column, and extract the resulting dataframe to a new CSV file
df = pd.read_csv('/content/drive/MyDrive/Project Dataset/clean_data.csv')

# %%
df['prev_sold_date'] = df['prev_sold_date'].where(df['prev_sold_date'].isnull(), 1)

# %%
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot        state  \
# 0     103378.0  for_sale  105000.0    3     2      0.12  Puerto Rico
# 1      52707.0  for_sale   80000.0    4     2      0.08  Puerto Rico
# 2     103379.0  for_sale   67000.0    2     1      0.15  Puerto Rico
# 3      31239.0  for_sale  145000.0    4     2      0.10  Puerto Rico
# 4     103378.0  for_sale  179000.0    4     3      0.46  Puerto Rico
#
#    house_size prev_sold_date
# 0       920.0            NaN
# 1      1527.0            NaN
# 2       748.0            NaN
# 3      1800.0            NaN
# 4      2520.0            NaN

# %%
df['prev_sold_date'] = df['prev_sold_date'].fillna(0)

# %%
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot        state  \
# 0     103378.0  for_sale  105000.0    3     2      0.12  Puerto Rico
# 1      52707.0  for_sale   80000.0    4     2      0.08  Puerto Rico
# 2     103379.0  for_sale   67000.0    2     1      0.15  Puerto Rico
# 3      31239.0  for_sale  145000.0    4     2      0.10  Puerto Rico
# 4     103378.0  for_sale  179000.0    4     3      0.46  Puerto Rico
#
#    house_size  prev_sold_date
# 0       920.0               0
# 1      1527.0               0
# 2       748.0               0
# 3      1800.0               0
# 4      2520.0               0

# %%
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot        state  \
# 0     103378.0  for_sale  105000.0    3     2      0.12  Puerto Rico
# 1      52707.0  for_sale   80000.0    4     2      0.08  Puerto Rico
# 2     103379.0  for_sale   67000.0    2     1      0.15  Puerto Rico
# 3      31239.0  for_sale  145000.0    4     2      0.10  Puerto Rico
# 4     103378.0  for_sale  179000.0    4     3      0.46  Puerto Rico
#
#    house_size  prev_sold_date
# 0       920.0               0
# 1      1527.0               0
# 2       748.0               0
# 3      1800.0               0
# 4      2520.0               0

# %%
count_one =df.loc[df['prev_sold_date'] == 1]

# %%
count_one.shape
# Out:
# (1089909, 9)

# %%
df.shape
# Out:
# (1360716, 9)

# %%
df=df.drop(['brokered_by'],axis=1)

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot        state  house_size  \
# 0  for_sale  105000.0    3     2      0.12  Puerto Rico       920.0
# 1  for_sale   80000.0    4     2      0.08  Puerto Rico      1527.0
# 2  for_sale   67000.0    2     1      0.15  Puerto Rico       748.0
# 3  for_sale  145000.0    4     2      0.10  Puerto Rico      1800.0
# 4  for_sale  179000.0    4     3      0.46  Puerto Rico      2520.0
#
#    prev_sold_date
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
df = pd.get_dummies(df, columns=['status','state'])

# %%
df.head()
# Out:
#       price  bed  bath  acre_lot  house_size  prev_sold_date  status_for_sale  \
# 0  105000.0    3     2      0.12       920.0               0             True
# 1   80000.0    4     2      0.08      1527.0               0             True
# 2   67000.0    2     1      0.15       748.0               0             True
# 3  145000.0    4     2      0.10      1800.0               0             True
# 4  179000.0    4     3      0.46      2520.0               0             True
#
#    status_sold  state_Alabama  state_Alaska  ...  state_Tennessee  \
# 0        False          False         False  ...            False
# 1        False          False         False  ...            False
# 2        False          False         False  ...            False
# 3        False          False         False  ...            False
# 4        False          False         False  ...            False
#
#    state_Texas  state_Utah  state_Vermont  state_Virgin Islands  \
# 0        False       False          False                 False
# 1        False       False          False                 False
# 2        False       False          False                 False
# 3        False       False          False                 False
# 4        False       False          False                 False
#
#    state_Virginia  state_Washington  state_West Virginia  state_Wisconsin  \
# 0           False             False                False            False
# 1           False             False                False            False
# 2           False             False                False            False
# 3           False             False                False            False
# 4           False             False                False            False
#
#    state_Wyoming
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 62 columns]

# %%
df.drop(['status','state'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c82dd294d2de> in <cell line: 1>()
# ----> 1 df.drop(['status','state'], axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4751                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4752             else:
# -> 4753                 new_axis = axis.drop(labels, errors=errors)
#    4754             indexer = axis.get_indexer(new_axis)
#    4755
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6998         if mask.any():
#    6999             if errors != "ignore":
# -> 7000                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001             indexer = indexer[~mask]
#    7002         return self.delete(indexer)
#
# KeyError: "['status', 'state'] not found in axis"

# %%
df.to_csv('dummy_encoded_data.csv', index=False)
